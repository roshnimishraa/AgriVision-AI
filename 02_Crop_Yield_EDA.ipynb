# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os
from pathlib import Path

# Portable data path. The original notebooks hardcoded Windows-style separators,
# which fail on macOS and Linux -- and in notebook 03 the path string was not a
# raw string, so the separators doubled as invalid escape sequences (a
# SyntaxWarning on Python 3.12+).
DATA_DIR = Path(os.environ.get("AGRIVISION_DATA", "data")) / "CropYield"

# %%
yield_df = pd.read_csv(DATA_DIR / "yield_df.csv")

# %%
yield_df.drop("Unnamed: 0", axis=1, inplace=True)

yield_df.head()
# Out:
#       Area         Item  Year  hg/ha_yield  average_rain_fall_mm_per_year  \
# 0  Albania        Maize  1990        36613                         1485.0
# 1  Albania     Potatoes  1990        66667                         1485.0
# 2  Albania  Rice, paddy  1990        23333                         1485.0
# 3  Albania      Sorghum  1990        12500                         1485.0
# 4  Albania     Soybeans  1990         7000                         1485.0
#
#    pesticides_tonnes  avg_temp
# 0              121.0     16.37
# 1              121.0     16.37
# 2              121.0     16.37
# 3              121.0     16.37
# 4              121.0     16.37

# %%
print("Shape :", yield_df.shape)

print("\nColumns\n")

print(yield_df.columns)
# Out:
# Shape : (28242, 7)
#
# Columns
#
# Index(['Area', 'Item', 'Year', 'hg/ha_yield', 'average_rain_fall_mm_per_year',
#        'pesticides_tonnes', 'avg_temp'],
#       dtype='object')

# %%
yield_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28242 entries, 0 to 28241
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Area                           28242 non-null  object
#  1   Item                           28242 non-null  object
#  2   Year                           28242 non-null  int64
#  3   hg/ha_yield                    28242 non-null  int64
#  4   average_rain_fall_mm_per_year  28242 non-null  float64
#  5   pesticides_tonnes              28242 non-null  float64
#  6   avg_temp                       28242 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 1.5+ MB

# %%
yield_df.describe()
# Out:
#                Year    hg/ha_yield  average_rain_fall_mm_per_year  \
# count  28242.000000   28242.000000                    28242.00000
# mean    2001.544296   77053.332094                     1149.05598
# std        7.051905   84956.612897                      709.81215
# min     1990.000000      50.000000                       51.00000
# 25%     1995.000000   19919.250000                      593.00000
# 50%     2001.000000   38295.000000                     1083.00000
# 75%     2008.000000  104676.750000                     1668.00000
# max     2013.000000  501412.000000                     3240.00000
#
#        pesticides_tonnes      avg_temp
# count       28242.000000  28242.000000
# mean        37076.909344     20.542627
# std         59958.784665      6.312051
# min             0.040000      1.300000
# 25%          1702.000000     16.702500
# 50%         17529.440000     21.510000
# 75%         48687.880000     26.000000
# max        367778.000000     30.650000

# %%
plt.figure(figsize=(10,5))

sns.countplot(
    data=yield_df,
    x="Item",
    order=yield_df["Item"].value_counts().index
)

plt.xticks(rotation=45)

plt.title("Distribution of Crop Records")

plt.xlabel("Crop")

plt.ylabel("Count")

plt.show()

# %%
plt.figure(figsize=(18,8))

sns.countplot(
    data=yield_df,
    x="Area",
    order=yield_df["Area"].value_counts().index
)

plt.xticks(rotation=90)

plt.title("Country Distribution")

plt.xlabel("Country")

plt.ylabel("Count")

plt.show()

# %%
plt.figure(figsize=(10,6))

sns.histplot(
    yield_df["hg/ha_yield"],
    bins=40,
    kde=True
)

plt.title("Yield Distribution")

plt.xlabel("Yield (hg/ha)")

plt.show()
# Out:
# /Users/rishabh/miniforge3/envs/agrivision-app/lib/python3.11/site-packages/scipy/_lib/_util.py:1235: RuntimeWarning: divide by zero encountered in vecdot
#   return np.vecdot(x1, x2, axis=axis)
# /Users/rishabh/miniforge3/envs/agrivision-app/lib/python3.11/site-packages/scipy/_lib/_util.py:1235: RuntimeWarning: overflow encountered in vecdot
#   return np.vecdot(x1, x2, axis=axis)
# /Users/rishabh/miniforge3/envs/agrivision-app/lib/python3.11/site-packages/scipy/_lib/_util.py:1235: RuntimeWarning: invalid value encountered in vecdot
#   return np.vecdot(x1, x2, axis=axis)

# %%
plt.figure(figsize=(10,6))

sns.histplot(
    yield_df["average_rain_fall_mm_per_year"],
    bins=30,
    kde=True
)

plt.title("Rainfall Distribution")

plt.xlabel("Rainfall")

plt.show()
# Out:
# /Users/rishabh/miniforge3/envs/agrivision-app/lib/python3.11/site-packages/scipy/_lib/_util.py:1235: RuntimeWarning: divide by zero encountered in vecdot
#   return np.vecdot(x1, x2, axis=axis)
# /Users/rishabh/miniforge3/envs/agrivision-app/lib/python3.11/site-packages/scipy/_lib/_util.py:1235: RuntimeWarning: overflow encountered in vecdot
#   return np.vecdot(x1, x2, axis=axis)
# /Users/rishabh/miniforge3/envs/agrivision-app/lib/python3.11/site-packages/scipy/_lib/_util.py:1235: RuntimeWarning: invalid value encountered in vecdot
#   return np.vecdot(x1, x2, axis=axis)

# %%
plt.figure(figsize=(10,6))

sns.histplot(
    yield_df["avg_temp"],
    bins=30,
    kde=True
)

plt.title("Average Temperature Distribution")

plt.xlabel("Temperature")

plt.show()
# Out:
# /Users/rishabh/miniforge3/envs/agrivision-app/lib/python3.11/site-packages/scipy/_lib/_util.py:1235: RuntimeWarning: divide by zero encountered in vecdot
#   return np.vecdot(x1, x2, axis=axis)
# /Users/rishabh/miniforge3/envs/agrivision-app/lib/python3.11/site-packages/scipy/_lib/_util.py:1235: RuntimeWarning: overflow encountered in vecdot
#   return np.vecdot(x1, x2, axis=axis)
# /Users/rishabh/miniforge3/envs/agrivision-app/lib/python3.11/site-packages/scipy/_lib/_util.py:1235: RuntimeWarning: invalid value encountered in vecdot
#   return np.vecdot(x1, x2, axis=axis)

# %%
plt.figure(figsize=(10,6))

sns.histplot(
    yield_df["pesticides_tonnes"],
    bins=30,
    kde=True
)

plt.title("Pesticides Distribution")

plt.xlabel("Pesticides")

plt.show()
# Out:
# /Users/rishabh/miniforge3/envs/agrivision-app/lib/python3.11/site-packages/scipy/_lib/_util.py:1235: RuntimeWarning: divide by zero encountered in vecdot
#   return np.vecdot(x1, x2, axis=axis)
# /Users/rishabh/miniforge3/envs/agrivision-app/lib/python3.11/site-packages/scipy/_lib/_util.py:1235: RuntimeWarning: overflow encountered in vecdot
#   return np.vecdot(x1, x2, axis=axis)
# /Users/rishabh/miniforge3/envs/agrivision-app/lib/python3.11/site-packages/scipy/_lib/_util.py:1235: RuntimeWarning: invalid value encountered in vecdot
#   return np.vecdot(x1, x2, axis=axis)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

corr = yield_df.select_dtypes(include=['int64', 'float64']).corr()

sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
    linewidths=0.5
)

plt.title("Correlation Heatmap")
plt.show()

# %%
numerical_columns = [
    "hg/ha_yield",
    "average_rain_fall_mm_per_year",
    "pesticides_tonnes",
    "avg_temp"
]

for col in numerical_columns:
    plt.figure(figsize=(8,4))
    sns.boxplot(x=yield_df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %% [markdown]
# ## Summary
#
# 1. The final dataset (yield_df.csv) contains 28,242 records and 7 useful features.
#
# 2. Data covers 10 crop types.
#
# 3. Records span from 1990 to 2013.
#
# 4. No missing values were found in the final dataset.
#
# 5. No duplicate records were present.
#
# 6. The unnecessary Unnamed: 0 column was removed.
#
# 7. Potatoes and Maize have the highest number of records.
#
# 8. India contains the highest number of observations.
#
# 9. Yield and pesticide usage are positively skewed.
#
# 10. Rainfall shows multiple peaks due to different climatic regions.
#
# 11. Temperature approximately follows a normal distribution.
#
# 12. Correlation analysis indicates no strong multicollinearity among numerical features.
#
# 13. Yield and pesticide variables contain outliers, but they represent genuine agricultural data and were retained.
#
# 14. The dataset is clean and ready for machine learning model development.
